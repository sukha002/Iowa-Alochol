# %% [markdown]
# ## 1. Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("1. Libraries Imported Successfully")
# Out:
# 1. Libraries Imported Successfully

# %% [markdown]
# ## 2. Acquires the Dataset

# %%
file = ("Iowa_Liquor_Sale.csv")
data = pd.read_csv(file)
print("2. File Loaded Successfully")
# Out:
# 2. File Loaded Successfully

# %% [markdown]
# ### 2.1 Dataset Description

# %% [markdown]
# #### 2.1.1 Top ten rows of DataFrame

# %%
data.head(10)
# Out:
#    invoice_line_no                     date  store  \
# 0  INV-06374900005  2017-07-31T00:00:00.000   4296
# 1  INV-06490900046  2017-08-04T00:00:00.000   3963
# 2  INV-06394500014  2017-07-31T00:00:00.000   2459
# 3  INV-06408400051  2017-08-01T00:00:00.000   5124
# 4  INV-06276700025  2017-07-25T00:00:00.000   5042
# 5  INV-06293800125  2017-07-26T00:00:00.000   2616
# 6  INV-06335500001  2017-07-27T00:00:00.000   4379
# 7  INV-06334100037  2017-07-27T00:00:00.000   5129
# 8  INV-06273400006  2017-07-25T00:00:00.000   5219
# 9  INV-06494700047  2017-08-07T00:00:00.000   4945
#
#                                name              address             city  \
# 0                   CIRCLE B MARKET          111 MAIN ST        KEOSAUQUA
# 1  TOBACCO HUT #14 / COUNCIL BLUFFS      1925 W BROADWAY   COUNCIL BLUFFS
# 2                    REINHART FOODS  200 STATE PO BOX 98   GUTHRIE CENTER
# 3        PRICE CHOPPER  /  JOHNSTON     5440 NW  86TH ST         JOHNSTON
# ...

# %% [markdown]
# #### 2.1.2 last ten rows of DataFrame

# %%
data.tail(10)
# Out:
#      invoice_line_no                     date  store  \
# 990  INV-06326700021  2017-07-27T00:00:00.000   4461
# 991  INV-06460900046  2017-08-03T00:00:00.000   2517
# 992  INV-06368800146  2017-07-31T00:00:00.000   2560
# 993  INV-06311400066  2017-07-26T00:00:00.000   5351
# 994  INV-06453200006  2017-08-03T00:00:00.000   5029
# 995  INV-06439700064  2017-08-02T00:00:00.000   2536
# 996  INV-06453600021  2017-08-03T00:00:00.000   4847
# 997  INV-06498300047  2017-08-07T00:00:00.000   3773
# 998  INV-06309800016  2017-07-26T00:00:00.000   4630
# 999  INV-06394500011  2017-07-31T00:00:00.000   2459
#
#                                  name                     address  \
# 990  QUIK TRIP #503 / WINDSOR HEIGHTS             7220 HICKMAN RD
# 991     HY-VEE FOOD STORE #1 / NEWTON      1501 FIRST AVENUE EAST
# 992        HY-VEE FOOD STORE / MARION  3600 BUSINESS HWY 151 EAST
# 993                   DOWNTOWN LIQUOR                1203 5TH ST.
# ...

# %% [markdown]
# ### 2.2 Number of Rows and Columns ??

# %%
print("Number of columns in DataFrame are :" , data.shape[1] , "\nNumber of Rows in DataFrame are    :" , data.shape[0])
# Out:
# Number of columns in DataFrame are : 29
# Number of Rows in DataFrame are    : 1000

# %% [markdown]
# ### 2.3 Dataset Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   invoice_line_no              1000 non-null   object
#  1   date                         1000 non-null   object
#  2   store                        1000 non-null   int64
#  3   name                         1000 non-null   object
#  4   address                      989 non-null    object
#  5   city                         989 non-null    object
#  6   zipcode                      989 non-null    float64
#  7   store_location               895 non-null    object
#  8   county_number                989 non-null    float64
#  9   county                       989 non-null    object
#  10  category                     999 non-null    float64
#  11  category_name                999 non-null    object
#  12  vendor_no                    1000 non-null   int64
# ...

# %% [markdown]
# ### 2.4 Description of Data Frame

# %%
data.describe()
# Out:
#              store       zipcode  county_number      category    vendor_no  \
# count  1000.000000    989.000000     989.000000  9.990000e+02  1000.000000
# mean   3764.426000  51285.255814      55.155713  1.040873e+06   257.351000
# std    1037.230374    980.741153      27.925617  3.266636e+04   136.874521
# min    2106.000000  50003.000000       3.000000  1.011100e+06    35.000000
# 25%    2616.000000  50321.000000      30.000000  1.012300e+06   115.000000
# 50%    3834.000000  51103.000000      57.000000  1.031200e+06   260.000000
# 75%    4717.500000  52310.000000      77.000000  1.062400e+06   380.000000
# max    5443.000000  52807.000000      99.000000  1.701100e+06   962.000000
#
#               itemno         pack  bottle_volume_ml  state_bottle_cost  \
# count    1000.000000  1000.000000       1000.000000        1000.000000
# mean    44444.501000    12.226000        930.400000           9.920490
# std     46672.381336     7.621615        515.558329           6.190177
# ...

# %%
print(data['date'].min())
print(data['date'].max())
# Out:
# 2017-07-25T00:00:00.000
# 2017-08-08T00:00:00.000

# %% [markdown]
# ## 3. Data Cleaning

# %% [markdown]
# ### 3.1 Checking for Null Observations

# %%
data.isnull().sum()
# Out:
# invoice_line_no                  0
# date                             0
# store                            0
# name                             0
# address                         11
# city                            11
# zipcode                         11
# store_location                 105
# county_number                   11
# county                          11
# category                         1
# category_name                    1
# vendor_no                        0
# vendor_name                      0
# itemno                           0
# im_desc                          0
# pack                             0
# bottle_volume_ml                 0
# state_bottle_cost                0
# state_bottle_retail              0
# sale_bottles                     0
# sale_dollars                     0
# sale_liters                      0
# sale_gallons                     0
# :@computed_region_3r5t_5243    105
# :@computed_region_wnea_7qqw    105
# :@computed_region_i9mz_6gmt    105
# ...

# %% [markdown]
# #### 3.1.2 Removal of null observations

# %%
data = data.dropna(how='any',axis=0)

# %% [markdown]
# #### 3.1.3 Re-checking the null observations

# %%
data.isnull().sum()
# Out:
# invoice_line_no                0
# date                           0
# store                          0
# name                           0
# address                        0
# city                           0
# zipcode                        0
# store_location                 0
# county_number                  0
# county                         0
# category                       0
# category_name                  0
# vendor_no                      0
# vendor_name                    0
# itemno                         0
# im_desc                        0
# pack                           0
# bottle_volume_ml               0
# state_bottle_cost              0
# state_bottle_retail            0
# sale_bottles                   0
# sale_dollars                   0
# sale_liters                    0
# sale_gallons                   0
# :@computed_region_3r5t_5243    0
# :@computed_region_wnea_7qqw    0
# :@computed_region_i9mz_6gmt    0
# :@computed_region_uhgg_e8y2    0
# ...

# %% [markdown]
# ### 3.2 Checking the duplicate observations

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [invoice_line_no, date, store, name, address, city, zipcode, store_location, county_number, county, category, category_name, vendor_no, vendor_name, itemno, im_desc, pack, bottle_volume_ml, state_bottle_cost, state_bottle_retail, sale_bottles, sale_dollars, sale_liters, sale_gallons, :@computed_region_3r5t_5243, :@computed_region_wnea_7qqw, :@computed_region_i9mz_6gmt, :@computed_region_uhgg_e8y2, :@computed_region_e7ym_nrbf]
# Index: []
#
# [0 rows x 29 columns]

# %%
print(" The summary of the duplicated observation in all coloumns in given below \n", data[data.duplicated].sum())
# Out:
#  The summary of the duplicated observation in all coloumns in given below
#  invoice_line_no                0.0
# date                           0.0
# store                          0.0
# name                           0.0
# address                        0.0
# city                           0.0
# zipcode                        0.0
# store_location                 0.0
# county_number                  0.0
# county                         0.0
# category                       0.0
# category_name                  0.0
# vendor_no                      0.0
# vendor_name                    0.0
# itemno                         0.0
# im_desc                        0.0
# pack                           0.0
# bottle_volume_ml               0.0
# state_bottle_cost              0.0
# state_bottle_retail            0.0
# sale_bottles                   0.0
# sale_dollars                   0.0
# sale_liters                    0.0
# sale_gallons                   0.0
# ...

# %% [markdown]
# ### 3.3
